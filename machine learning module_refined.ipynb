# %% [markdown]
# ## Importing dependencies

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import psycopg2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as ns
from pathlib import Path
from collections import Counter
from sqlalchemy import create_engine

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Connecting to the database

# %%
#connect to pgadmin database

#https://blog.panoply.io/connecting-jupyter-notebook-with-postgresql-for-python-data-analysis
#from config import password

addy = "localhost"
port = "5432"
username = "postgres"
pswd = ""
dbname = "Formula_1"

#string that contains the postgres login info
postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'
    .format(username=username,
    password= pswd,
    ipaddress=addy,
    port=port,
    dbname=dbname))

#connection
connection = create_engine(postgres_str)

# %%
#confirming the data connect and loading data to pandas dataframe

#we'll use the table with all our modeling info
df = pd.read_sql_query('''SELECT * FROM sim_data ;''', connection)
#df.count()
df.head()
# Out:
#                race_name        date         full_name  finish_position  \
# 0  Australian Grand Prix  2019-03-17   Valtteri Bottas              1.0
# 1  Australian Grand Prix  2019-03-17    Lewis Hamilton              2.0
# 2  Australian Grand Prix  2019-03-17    Max Verstappen              3.0
# 3  Australian Grand Prix  2019-03-17  Sebastian Vettel              4.0
# 4  Australian Grand Prix  2019-03-17   Charles Leclerc              5.0
#
#    grid_position  avg_humidity  avg_air_pressure  rainfall  avg_airtemp  \
# 0              2     70.453279       1015.334426     False    23.477869
# 1              1     70.453279       1015.334426     False    23.477869
# 2              4     70.453279       1015.334426     False    23.477869
# 3              3     70.453279       1015.334426     False    23.477869
# 4              5     70.453279       1015.334426     False    23.477869
#
#   downforce_level start_tyre end_tyre  num_stops                     q1  \
# 0            High       SOFT   MEDIUM        2.0 0 days 00:01:22.400000
# 1            High       SOFT   MEDIUM        2.0        0 days 00:01:22
# 2            High       SOFT   MEDIUM        2.0 0 days 00:01:22.900000
# 3            High       SOFT   MEDIUM        2.0 0 days 00:01:22.900000
# 4            High       SOFT     HARD        2.0        0 days 00:01:22
#
#                       q2                     q3
# 0 0 days 00:01:21.200000 0 days 00:01:20.600000
# 1        0 days 00:01:21 0 days 00:01:20.500000
# 2 0 days 00:01:21.700000 0 days 00:01:21.300000
# 3 0 days 00:01:21.900000 0 days 00:01:21.200000
# 4 0 days 00:01:21.700000 0 days 00:01:21.400000

# %% [markdown]
# ## Data cleanup/prep

# %%
##checking types
df.dtypes
# Out:
# race_name                    object
# date                         object
# full_name                    object
# finish_position             float64
# grid_position                 int64
# avg_humidity                float64
# avg_air_pressure            float64
# rainfall                       bool
# avg_airtemp                 float64
# downforce_level              object
# start_tyre                   object
# end_tyre                     object
# num_stops                   float64
# q1                  timedelta64[ns]
# q2                  timedelta64[ns]
# q3                  timedelta64[ns]
# dtype: object

# %%
#checking nulls
df.isnull().sum()
# Out:
# race_name             0
# date                  0
# full_name             0
# finish_position     147
# grid_position         0
# avg_humidity          0
# avg_air_pressure      0
# rainfall              0
# avg_airtemp           0
# downforce_level     420
# start_tyre           19
# end_tyre             19
# num_stops            19
# q1                   16
# q2                  295
# q3                  581
# dtype: int64

# %%
#dropping unneeded columns
clean_df = df.drop(['race_name','date','full_name','downforce_level'],axis=1)
clean_df.head()
# Out:
#    finish_position  grid_position  avg_humidity  avg_air_pressure  rainfall  \
# 0              1.0              2     70.453279       1015.334426     False
# 1              2.0              1     70.453279       1015.334426     False
# 2              3.0              4     70.453279       1015.334426     False
# 3              4.0              3     70.453279       1015.334426     False
# 4              5.0              5     70.453279       1015.334426     False
#
#    avg_airtemp start_tyre end_tyre  num_stops                     q1  \
# 0    23.477869       SOFT   MEDIUM        2.0 0 days 00:01:22.400000
# 1    23.477869       SOFT   MEDIUM        2.0        0 days 00:01:22
# 2    23.477869       SOFT   MEDIUM        2.0 0 days 00:01:22.900000
# 3    23.477869       SOFT   MEDIUM        2.0 0 days 00:01:22.900000
# 4    23.477869       SOFT     HARD        2.0        0 days 00:01:22
#
#                       q2                     q3
# 0 0 days 00:01:21.200000 0 days 00:01:20.600000
# 1        0 days 00:01:21 0 days 00:01:20.500000
# 2 0 days 00:01:21.700000 0 days 00:01:21.300000
# 3 0 days 00:01:21.900000 0 days 00:01:21.200000
# 4 0 days 00:01:21.700000 0 days 00:01:21.400000

# %%
#replacing null finish position with last place identifier
clean_df['finish_position'] = clean_df['finish_position'].fillna(20)
clean_df.isnull().sum()
# Out:
# finish_position       0
# grid_position         0
# avg_humidity          0
# avg_air_pressure      0
# rainfall              0
# avg_airtemp           0
# start_tyre           19
# end_tyre             19
# num_stops            19
# q1                   16
# q2                  295
# q3                  581
# dtype: int64

# %%
#finding min of q1, q2, q3 for minimum qualifying round times, storing as a new column
clean_df['qt_min'] = clean_df[['q1', 'q2', 'q3']].min(axis=1)
clean_df.head()
# Out:
#    finish_position  grid_position  avg_humidity  avg_air_pressure  rainfall  \
# 0              1.0              2     70.453279       1015.334426     False
# 1              2.0              1     70.453279       1015.334426     False
# 2              3.0              4     70.453279       1015.334426     False
# 3              4.0              3     70.453279       1015.334426     False
# 4              5.0              5     70.453279       1015.334426     False
#
#    avg_airtemp start_tyre end_tyre  num_stops                     q1  \
# 0    23.477869       SOFT   MEDIUM        2.0 0 days 00:01:22.400000
# 1    23.477869       SOFT   MEDIUM        2.0        0 days 00:01:22
# 2    23.477869       SOFT   MEDIUM        2.0 0 days 00:01:22.900000
# 3    23.477869       SOFT   MEDIUM        2.0 0 days 00:01:22.900000
# 4    23.477869       SOFT     HARD        2.0        0 days 00:01:22
#
#                       q2                     q3                 qt_min
# 0 0 days 00:01:21.200000 0 days 00:01:20.600000 0 days 00:01:20.600000
# 1        0 days 00:01:21 0 days 00:01:20.500000 0 days 00:01:20.500000
# 2 0 days 00:01:21.700000 0 days 00:01:21.300000 0 days 00:01:21.300000
# 3 0 days 00:01:21.900000 0 days 00:01:21.200000 0 days 00:01:21.200000
# 4 0 days 00:01:21.700000 0 days 00:01:21.400000 0 days 00:01:21.400000

# %%
#dropping unneeded qualification times prior to dropping all nulls to maintain as much data as possible
clean_df = clean_df.drop(['q1','q2','q3'],axis =1)
clean_df
# Out:
#       finish_position  grid_position  avg_humidity  avg_air_pressure  \
# 0                 1.0              2     70.453279       1015.334426
# 1                 2.0              1     70.453279       1015.334426
# 2                 3.0              4     70.453279       1015.334426
# 3                 4.0              3     70.453279       1015.334426
# 4                 5.0              5     70.453279       1015.334426
# ...               ...            ...           ...               ...
# 1131             20.0             20     76.203109       1013.797409
# 1132             20.0              5     76.203109       1013.797409
# 1133             20.0             14     76.203109       1013.797409
# 1134             20.0             17     76.203109       1013.797409
# 1135             20.0             19     76.203109       1013.797409
#
#       rainfall  avg_airtemp start_tyre end_tyre  num_stops  \
# 0        False    23.477869       SOFT   MEDIUM        2.0
# 1        False    23.477869       SOFT   MEDIUM        2.0
# 2        False    23.477869       SOFT   MEDIUM        2.0
# 3        False    23.477869       SOFT   MEDIUM        2.0
# 4        False    23.477869       SOFT     HARD        2.0
# ...        ...          ...        ...      ...        ...
# 1131     False    28.816062     MEDIUM     HARD        2.0
# 1132     False    28.816062     MEDIUM   MEDIUM        3.0
# 1133     False    28.816062     MEDIUM     HARD        3.0
# 1134     False    28.816062       HARD   MEDIUM        3.0
# 1135     False    28.816062     MEDIUM   MEDIUM        1.0
#
#                      qt_min
# 0    0 days 00:01:20.600000
# 1    0 days 00:01:20.500000
# 2    0 days 00:01:21.300000
# 3    0 days 00:01:21.200000
# 4    0 days 00:01:21.400000
# ...                     ...
# 1131 0 days 00:01:30.500000
# 1132 0 days 00:01:27.900000
# 1133 0 days 00:01:28.900000
# 1134 0 days 00:01:29.200000
# 1135 0 days 00:01:29.500000
#
# [1136 rows x 10 columns]

# %%
#rechecking nulls
clean_df.isnull().sum()
# Out:
# finish_position      0
# grid_position        0
# avg_humidity         0
# avg_air_pressure     0
# rainfall             0
# avg_airtemp          0
# start_tyre          19
# end_tyre            19
# num_stops           19
# qt_min              16
# dtype: int64

# %%
#drop all remaining nulls
clean_df = clean_df.dropna()
clean_df.isnull().sum()
# Out:
# finish_position     0
# grid_position       0
# avg_humidity        0
# avg_air_pressure    0
# rainfall            0
# avg_airtemp         0
# start_tyre          0
# end_tyre            0
# num_stops           0
# qt_min              0
# dtype: int64

# %%
#converting qt_min to nanoseconds and int64 to be able to run modeler, otherwise it throws an error
clean_df['qt_min_ns'] = clean_df['qt_min'].apply(lambda x: x.delta)
clean_df.dtypes
# Out:
# finish_position             float64
# grid_position                 int64
# avg_humidity                float64
# avg_air_pressure            float64
# rainfall                       bool
# avg_airtemp                 float64
# start_tyre                   object
# end_tyre                     object
# num_stops                   float64
# qt_min              timedelta64[ns]
# qt_min_ns                     int64
# dtype: object

# %%
#converting num_stops to integer

clean_df['num_stops'] = clean_df['num_stops'].astype(int)
clean_df
# Out:
#       finish_position  grid_position  avg_humidity  avg_air_pressure  \
# 0                 1.0              2     70.453279       1015.334426
# 1                 2.0              1     70.453279       1015.334426
# 2                 3.0              4     70.453279       1015.334426
# 3                 4.0              3     70.453279       1015.334426
# 4                 5.0              5     70.453279       1015.334426
# ...               ...            ...           ...               ...
# 1131             20.0             20     76.203109       1013.797409
# 1132             20.0              5     76.203109       1013.797409
# 1133             20.0             14     76.203109       1013.797409
# 1134             20.0             17     76.203109       1013.797409
# 1135             20.0             19     76.203109       1013.797409
#
#       rainfall  avg_airtemp start_tyre end_tyre  num_stops  \
# 0        False    23.477869       SOFT   MEDIUM          2
# 1        False    23.477869       SOFT   MEDIUM          2
# 2        False    23.477869       SOFT   MEDIUM          2
# 3        False    23.477869       SOFT   MEDIUM          2
# 4        False    23.477869       SOFT     HARD          2
# ...        ...          ...        ...      ...        ...
# 1131     False    28.816062     MEDIUM     HARD          2
# 1132     False    28.816062     MEDIUM   MEDIUM          3
# 1133     False    28.816062     MEDIUM     HARD          3
# 1134     False    28.816062       HARD   MEDIUM          3
# 1135     False    28.816062     MEDIUM   MEDIUM          1
#
#                      qt_min    qt_min_ns
# 0    0 days 00:01:20.600000  80600000000
# 1    0 days 00:01:20.500000  80500000000
# 2    0 days 00:01:21.300000  81300000000
# 3    0 days 00:01:21.200000  81200000000
# 4    0 days 00:01:21.400000  81400000000
# ...                     ...          ...
# 1131 0 days 00:01:30.500000  90500000000
# 1132 0 days 00:01:27.900000  87900000000
# 1133 0 days 00:01:28.900000  88900000000
# 1134 0 days 00:01:29.200000  89200000000
# 1135 0 days 00:01:29.500000  89500000000
#
# [1101 rows x 11 columns]

# %%
#converting rainfall to integers
clean_df['rainfall'] = clean_df['rainfall'].astype(int)
clean_df
# Out:
#       finish_position  grid_position  avg_humidity  avg_air_pressure  \
# 0                 1.0              2     70.453279       1015.334426
# 1                 2.0              1     70.453279       1015.334426
# 2                 3.0              4     70.453279       1015.334426
# 3                 4.0              3     70.453279       1015.334426
# 4                 5.0              5     70.453279       1015.334426
# ...               ...            ...           ...               ...
# 1131             20.0             20     76.203109       1013.797409
# 1132             20.0              5     76.203109       1013.797409
# 1133             20.0             14     76.203109       1013.797409
# 1134             20.0             17     76.203109       1013.797409
# 1135             20.0             19     76.203109       1013.797409
#
#       rainfall  avg_airtemp start_tyre end_tyre  num_stops  \
# 0            0    23.477869       SOFT   MEDIUM          2
# 1            0    23.477869       SOFT   MEDIUM          2
# 2            0    23.477869       SOFT   MEDIUM          2
# 3            0    23.477869       SOFT   MEDIUM          2
# 4            0    23.477869       SOFT     HARD          2
# ...        ...          ...        ...      ...        ...
# 1131         0    28.816062     MEDIUM     HARD          2
# 1132         0    28.816062     MEDIUM   MEDIUM          3
# 1133         0    28.816062     MEDIUM     HARD          3
# 1134         0    28.816062       HARD   MEDIUM          3
# 1135         0    28.816062     MEDIUM   MEDIUM          1
#
#                      qt_min    qt_min_ns
# 0    0 days 00:01:20.600000  80600000000
# 1    0 days 00:01:20.500000  80500000000
# 2    0 days 00:01:21.300000  81300000000
# 3    0 days 00:01:21.200000  81200000000
# 4    0 days 00:01:21.400000  81400000000
# ...                     ...          ...
# 1131 0 days 00:01:30.500000  90500000000
# 1132 0 days 00:01:27.900000  87900000000
# 1133 0 days 00:01:28.900000  88900000000
# 1134 0 days 00:01:29.200000  89200000000
# 1135 0 days 00:01:29.500000  89500000000
#
# [1101 rows x 11 columns]

# %%
#converting start_tyre and end_tyre to integers
tire_cats = {np.nan:0, 'SOFT':1,'MEDIUM':2,'HARD':3, 'INTERMEDIATE':4, 'WET':5}

clean_df['start_tyre'] = clean_df['start_tyre'].map(tire_cats)
clean_df['end_tyre'] = clean_df['end_tyre'].map(tire_cats)
clean_df.head()
# Out:
#    finish_position  grid_position  avg_humidity  avg_air_pressure  rainfall  \
# 0              1.0              2     70.453279       1015.334426         0
# 1              2.0              1     70.453279       1015.334426         0
# 2              3.0              4     70.453279       1015.334426         0
# 3              4.0              3     70.453279       1015.334426         0
# 4              5.0              5     70.453279       1015.334426         0
#
#    avg_airtemp  start_tyre  end_tyre  num_stops                 qt_min  \
# 0    23.477869           1         2          2 0 days 00:01:20.600000
# 1    23.477869           1         2          2 0 days 00:01:20.500000
# 2    23.477869           1         2          2 0 days 00:01:21.300000
# 3    23.477869           1         2          2 0 days 00:01:21.200000
# 4    23.477869           1         3          2 0 days 00:01:21.400000
#
#      qt_min_ns
# 0  80600000000
# 1  80500000000
# 2  81300000000
# 3  81200000000
# 4  81400000000

# %%
#creating Y value for model - if racers are in the top ten they get points
clean_df['top_ten'] = np.where(clean_df['finish_position'] <= 10, True,False)
clean_df = clean_df.drop(['qt_min'],axis=1)
clean_df.head(25)
# Out:
#     finish_position  grid_position  avg_humidity  avg_air_pressure  rainfall  \
# 0               1.0              2     70.453279       1015.334426         0
# 1               2.0              1     70.453279       1015.334426         0
# 2               3.0              4     70.453279       1015.334426         0
# 3               4.0              3     70.453279       1015.334426         0
# 4               5.0              5     70.453279       1015.334426         0
# 5               6.0              7     70.453279       1015.334426         0
# 6               7.0             11     70.453279       1015.334426         0
# 7               8.0              9     70.453279       1015.334426         0
# 8               9.0             16     70.453279       1015.334426         0
# 9              10.0             15     70.453279       1015.334426         0
# 10             11.0             17     70.453279       1015.334426         0
# 11             12.0              8     70.453279       1015.334426         0
# 12             13.0             10     70.453279       1015.334426         0
# 13             14.0             13     70.453279       1015.334426         0
# 14             15.0             14     70.453279       1015.334426         0
# 15             16.0             19     70.453279       1015.334426         0
# 16             17.0             20     70.453279       1015.334426         0
# 17             20.0             18     70.453279       1015.334426         0
# 18             20.0              6     70.453279       1015.334426         0
# 19             20.0             12     70.453279       1015.334426         0
# 20              1.0              3     53.372093       1003.437209         0
# 21              2.0              4     53.372093       1003.437209         0
# 22              3.0              1     53.372093       1003.437209         0
# 23              4.0              5     53.372093       1003.437209         0
# 24              5.0              2     53.372093       1003.437209         0
#
#     avg_airtemp  start_tyre  end_tyre  num_stops    qt_min_ns  top_ten
# 0     23.477869           1         2          2  80600000000     True
# 1     23.477869           1         2          2  80500000000     True
# 2     23.477869           1         2          2  81300000000     True
# 3     23.477869           1         2          2  81200000000     True
# 4     23.477869           1         3          2  81400000000     True
# 5     23.477869           1         2          2  82100000000     True
# 6     23.477869           1         3          2  82500000000     True
# 7     23.477869           1         2          2  82300000000     True
# 8     23.477869           2         3          2  83000000000     True
# 9     23.477869           2         3          2  82500000000     True
# 10    23.477869           2         1          2  83000000000    False
# 11    23.477869           1         3          2  82300000000    False
# 12    23.477869           1         3          2  82500000000    False
# 13    23.477869           1         2          2  82600000000    False
# 14    23.477869           2         1          2  82400000000    False
# 15    23.477869           2         3          3  84400000000    False
# 16    23.477869           3         1          4  86100000000    False
# 17    23.477869           1         1          1  83100000000    False
# 18    23.477869           1         2          2  81800000000    False
# 19    23.477869           1         3          2  82600000000    False
# 20    26.210853           1         2          3  88200000000     True
# 21    26.210853           1         1          3  88300000000     True
# 22    26.210853           1         2          3  87900000000     True
# 23    26.210853           1         2          3  88800000000     True
# 24    26.210853           1         1          4  88200000000     True

# %% [markdown]
# ## Checking data prior to loading into model

# %%
#confirming no nulls
clean_df.isnull().sum()
# Out:
# finish_position     0
# grid_position       0
# avg_humidity        0
# avg_air_pressure    0
# rainfall            0
# avg_airtemp         0
# start_tyre          0
# end_tyre            0
# num_stops           0
# qt_min_ns           0
# top_ten             0
# dtype: int64

# %%
#confirming counts
clean_df.count()
# Out:
# finish_position     1101
# grid_position       1101
# avg_humidity        1101
# avg_air_pressure    1101
# rainfall            1101
# avg_airtemp         1101
# start_tyre          1101
# end_tyre            1101
# num_stops           1101
# qt_min_ns           1101
# top_ten             1101
# dtype: int64

# %%
#confirming data types
clean_df.dtypes
# Out:
# finish_position     float64
# grid_position         int64
# avg_humidity        float64
# avg_air_pressure    float64
# rainfall              int32
# avg_airtemp         float64
# start_tyre            int64
# end_tyre              int64
# num_stops             int32
# qt_min_ns             int64
# top_ten                bool
# dtype: object

# %% [markdown]
# ## Training the model

# %%
#creating features, using all available columns other than predetermined Y - top ten

# Create our features
X = clean_df.drop(columns = 'top_ten')
X = pd.get_dummies(X)
#X.head()
#Create our target
y = clean_df['top_ten']

# %%
#splitting data into training and testing, using a test size of 33%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .75, random_state=1)

# %%
#preparing model
classifier = LogisticRegression(solver='lbfgs', random_state=1)
classifier
# Out:
# LogisticRegression(random_state=1)

# %%
#loading model
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=1)

# %%
#putting predictions into a dataframe
y_pred = classifier.predict(X_test)
pd.DataFrame({"Prediction": y_pred, "Actual": y_test})
# Out:
#       Prediction  Actual
# 556         True   False
# 1011        True   False
# 375         True   False
# 604         True    True
# 879         True    True
# ...          ...     ...
# 51          True   False
# 1043        True    True
# 652         True   False
# 806         True    True
# 280         True    True
#
# [826 rows x 2 columns]

# %%
#checking accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.49878934624697335

# %%
#checking confusion matrix
predictions = classifier.predict(X_test)
confusion_matrix(y_test, predictions)
# Out:
# array([[  0, 414],
#        [  0, 412]], dtype=int64)

# %%
#determining the importance of features
importance = classifier.coef_
importance
# Out:
# array([[-4.31363650e-21, -2.49705990e-21,  3.04631230e-22,
#          5.62353578e-21,  1.75814157e-25,  1.31668769e-22,
#         -6.39824526e-23,  7.03322477e-23,  8.68652460e-23,
#         -4.14106138e-14]])
